# %% [markdown]
# <a href="https://colab.research.google.com/github/trzynogazyrafa/schema-therapy/blob/main/SMI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "/content/drive/MyDrive/bogus2.xlsx"

# %%
df = pd.read_excel(path)

# %%
srednie = df.groupby("tryb")["pacjent1"].mean()
srednie
# Out:
# tryb
# AC     1.400000
# BA     1.333333
# CS     1.571429
# DP     2.444444
# DPa    4.500000
# DSS    3.750000
# EC     1.100000
# HA     5.500000
# HC     2.800000
# IC     1.444444
# PP     2.500000
# SA     2.900000
# UC     1.166667
# VC     3.300000
# Name: pacjent1, dtype: float64

# %%
fig = plt.figure(figsize = (15, 5))
plt.plot(srednie)
